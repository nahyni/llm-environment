# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("서울시 부동산 실거래가 정보.csv", encoding = 'cp949')
df
# Out:
# c:\Users\82103\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        접수연도  자치구코드 자치구명  법정동코드  법정동명  지번구분 지번구분명     본번    부번           건물명  \
# 0      2024  11215  광진구  10200    능동   1.0    대지  240.0   7.0       (240-7)
# 1      2024  11290  성북구  13300   정릉동   1.0    대지  494.0   0.0     중앙하이츠빌1단지
# 2      2024  11620  관악구  10100   봉천동   1.0    대지  969.0  51.0      리더스 오피스텔
# 3      2024  11260  중랑구  10300   중화동   1.0    대지  329.0  25.0         해피리움빌
# 4      2024  11470  양천구  10100   신정동   1.0    대지  325.0   0.0      목동신시가지11
# ...     ...    ...  ...    ...   ...   ...   ...    ...   ...           ...
# 71127  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71128  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# ...

# %%
df = pd.read_csv("서울시 부동산 실거래가 정보.csv", encoding = 'cp949')
df['자치구명'].fillna('강북구', inplace=True)

df['부번'] = df['부번'].replace(0, np.nan)
df = df.dropna(subset=['본번'])
df['본번']=pd.to_numeric(df['본번'], errors='coerce').astype('Int64')
df['부번']=pd.to_numeric(df['부번'], errors='coerce').astype('Int64')
# Out:
# c:\Users\82103\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#        접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명   본번    부번           건물명  ...  \
# 0      2024  11215  광진구  10200   능동   1.0    대지  240     7       (240-7)  ...
# 1      2024  11290  성북구  13300  정릉동   1.0    대지  494  <NA>     중앙하이츠빌1단지  ...
# 2      2024  11620  관악구  10100  봉천동   1.0    대지  969    51      리더스 오피스텔  ...
# 3      2024  11260  중랑구  10300  중화동   1.0    대지  329    25         해피리움빌  ...
# 4      2024  11470  양천구  10100  신정동   1.0    대지  325  <NA>      목동신시가지11  ...
# ...     ...    ...  ...    ...  ...   ...   ...  ...   ...           ...  ...
# 71125  2024  11215  광진구  10700  화양동   1.0    대지   17    68  세종에버그린(101동)  ...
# 71126  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71127  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71128  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71129  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
#
# ...

# %%
# NaN 값이 있는 행 확인
nan_rows = df[df['자치구명'].isna()]
nan_rows
# Out:
#        접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명    본번    부번  \
# 67642  2024  26230  NaN  10100  미아동   1.0    대지
#
#                         건물명  ...  물건금액(만원)  건물면적(㎡)  토지면적(㎡)    층  권리구분 취소일  \
# 67642  2020년 2차 행복주택 입주자 모집  ...     42450    72.13      0.0  5.0   분양권 NaN
#
#        건축년도  건물용도  신고구분 신고한 개업공인중개사 시군구명
# 67642   0.0   아파트  중개거래          부산 부산진구
#
# [1 rows x 21 columns]

# %%
import numpy as np

def create_address(row):
    if pd.isna(row['부번']):
        return f"{row['자치구명']} {row['법정동명']} {row['본번']}"
    else:
        return f"{row['자치구명']} {row['법정동명']} {row['본번']}-{row['부번']}"

df['주소'] = df.apply(create_address, axis=1)
df
# Out:
#        접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명   본번    부번           건물명  ...  \
# 0      2024  11215  광진구  10200   능동   1.0    대지  240     7       (240-7)  ...
# 1      2024  11290  성북구  13300  정릉동   1.0    대지  494  <NA>     중앙하이츠빌1단지  ...
# 2      2024  11620  관악구  10100  봉천동   1.0    대지  969    51      리더스 오피스텔  ...
# 3      2024  11260  중랑구  10300  중화동   1.0    대지  329    25         해피리움빌  ...
# 4      2024  11470  양천구  10100  신정동   1.0    대지  325  <NA>      목동신시가지11  ...
# ...     ...    ...  ...    ...  ...   ...   ...  ...   ...           ...  ...
# 71125  2024  11215  광진구  10700  화양동   1.0    대지   17    68  세종에버그린(101동)  ...
# 71126  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71127  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71128  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71129  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
#
# ...

# %%
df['주소'] = '서울시 ' + df['주소']
df
# Out:
#        접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명   본번    부번           건물명  ...  \
# 0      2024  11215  광진구  10200   능동   1.0    대지  240     7       (240-7)  ...
# 1      2024  11290  성북구  13300  정릉동   1.0    대지  494  <NA>     중앙하이츠빌1단지  ...
# 2      2024  11620  관악구  10100  봉천동   1.0    대지  969    51      리더스 오피스텔  ...
# 3      2024  11260  중랑구  10300  중화동   1.0    대지  329    25         해피리움빌  ...
# 4      2024  11470  양천구  10100  신정동   1.0    대지  325  <NA>      목동신시가지11  ...
# ...     ...    ...  ...    ...  ...   ...   ...  ...   ...           ...  ...
# 71125  2024  11215  광진구  10700  화양동   1.0    대지   17    68  세종에버그린(101동)  ...
# 71126  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71127  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71128  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
# 71129  2024  11530  구로구  10700  개봉동   1.0    대지  170    33  금석연립(170-33)  ...
#
# ...

# %%
df.to_csv('주소3.csv', index=False)

# %%
len(df['법정동명'].unique())
# Out:
# 385

# %%
len(df['법정동명'].unique())
# Out:
# 385

# %%
df.columns
# Out:
# Index(['접수연도', '자치구코드', '자치구명', '법정동코드', '법정동명', '지번구분', '지번구분명', '본번', '부번',
#        '건물명', '계약일', '물건금액(만원)', '건물면적(㎡)', '토지면적(㎡)', '층', '권리구분', '취소일',
#        '건축년도', '건물용도', '신고구분', '신고한 개업공인중개사 시군구명'],
#       dtype='object')

# %%
# 자치구+법정동 코드를 숫자(numeric) 형식으로 변환
# 자치구+법정동 코드를 Int64 형식으로 변환
df['자치구+법정동 코드'] = (df['자치구코드'].astype(str) + df['법정동코드'].astype(str))
df
# Out:
#        접수연도  자치구코드 자치구명  법정동코드  법정동명  지번구분 지번구분명     본번    부번           건물명  \
# 0      2024  11215  광진구  10200    능동   1.0    대지  240.0   7.0       (240-7)
# 1      2024  11290  성북구  13300   정릉동   1.0    대지  494.0   0.0     중앙하이츠빌1단지
# 2      2024  11620  관악구  10100   봉천동   1.0    대지  969.0  51.0      리더스 오피스텔
# 3      2024  11260  중랑구  10300   중화동   1.0    대지  329.0  25.0         해피리움빌
# 4      2024  11470  양천구  10100   신정동   1.0    대지  325.0   0.0      목동신시가지11
# ...     ...    ...  ...    ...   ...   ...   ...    ...   ...           ...
# 71127  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71128  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71129  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71130  2024  11440  마포구  11000  노고산동   NaN   NaN    NaN   NaN           NaN
# 71131  2024  11305  강북구  10100   미아동   NaN   NaN    NaN   NaN           NaN
#
# ...

# %%
df
# Out:
#        접수연도  자치구코드 자치구명  법정동코드  법정동명  지번구분 지번구분명     본번    부번           건물명  \
# 0      2024  11215  광진구  10200    능동   1.0    대지  240.0   7.0       (240-7)
# 1      2024  11290  성북구  13300   정릉동   1.0    대지  494.0   0.0     중앙하이츠빌1단지
# 2      2024  11620  관악구  10100   봉천동   1.0    대지  969.0  51.0      리더스 오피스텔
# 3      2024  11260  중랑구  10300   중화동   1.0    대지  329.0  25.0         해피리움빌
# 4      2024  11470  양천구  10100   신정동   1.0    대지  325.0   0.0      목동신시가지11
# ...     ...    ...  ...    ...   ...   ...   ...    ...   ...           ...
# 71127  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71128  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71129  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71130  2024  11440  마포구  11000  노고산동   NaN   NaN    NaN   NaN           NaN
# 71131  2024  11305  강북구  10100   미아동   NaN   NaN    NaN   NaN           NaN
#
# ...

# %%
unique_mapping = df_ref.groupby('법정동코드').filter(lambda x: len(x) == 1)

# df_ref의 1:1 매핑된 행정동코드를 딕셔너리로 변환
mapping = unique_mapping.set_index('법정동코드')['행정동코드'].to_dict()

# df와 df_ref를 병합하여 '행정동코드' 값을 추가
df = df.copy()
df['행정동코드'] = df['자치구+법정동 코드'].map(mapping)

# '행정동코드'가 없는 경우는 0으로 설정
df['행정동코드'] = df['행정동코드'].fillna('0')

# %%
df[df['행정동코드']=='0']
# Out:
#        접수연도  자치구코드 자치구명  법정동코드  법정동명  지번구분 지번구분명     본번    부번           건물명  \
# 0      2024  11215  광진구  10200    능동   1.0    대지  240.0   7.0       (240-7)
# 1      2024  11290  성북구  13300   정릉동   1.0    대지  494.0   0.0     중앙하이츠빌1단지
# 2      2024  11620  관악구  10100   봉천동   1.0    대지  969.0  51.0      리더스 오피스텔
# 3      2024  11260  중랑구  10300   중화동   1.0    대지  329.0  25.0         해피리움빌
# 4      2024  11470  양천구  10100   신정동   1.0    대지  325.0   0.0      목동신시가지11
# ...     ...    ...  ...    ...   ...   ...   ...    ...   ...           ...
# 71127  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71128  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71129  2024  11530  구로구  10700   개봉동   1.0    대지   0170  0033  금석연립(170-33)
# 71130  2024  11440  마포구  11000  노고산동   NaN   NaN    NaN   NaN           NaN
# 71131  2024  11305  강북구  10100   미아동   NaN   NaN    NaN   NaN           NaN
#
# ...

# %%
df_ref = pd.read_csv('행정동 법정동 mapping.csv')
df_ref = df_ref[df_ref['시도명'] == '서울특별시']
df_ref
# Out:
#           행정동코드    시도명 시군구명   읍면동명       법정동코드    동리명      생성일자  말소일자
# 0    1100000000  서울특별시  NaN    NaN  1100000000  서울특별시  19880423   NaN
# 1    1111000000  서울특별시  종로구    NaN  1111000000    종로구  19880423   NaN
# 2    1111051500  서울특별시  종로구  청운효자동  1111010100    청운동  20081101   NaN
# 3    1111051500  서울특별시  종로구  청운효자동  1111010200    신교동  20081101   NaN
# 4    1111051500  서울특별시  종로구  청운효자동  1111010300    궁정동  20081101   NaN
# ..          ...    ...  ...    ...         ...    ...       ...   ...
# 766  1174065000  서울특별시  강동구  성내제2동  1174010800    성내동  19880423   NaN
# 767  1174066000  서울특별시  강동구  성내제3동  1174010800    성내동  19880423   NaN
# 768  1174068500  서울특별시  강동구     길동  1174010500     길동  20080707   NaN
# 769  1174069000  서울특별시  강동구  둔촌제1동  1174010600    둔촌동  19880423   NaN
# 770  1174070000  서울특별시  강동구  둔촌제2동  1174010600    둔촌동  19880423   NaN
#
# [771 rows x 8 columns]

# %%
len(df_ref['읍면동명'].unique())
# Out:
# 426

# %%
df_ref['법정동코드'] = df_ref['법정동코드'].astype(str)
df_ref['행정동코드'] = df_ref['행정동코드'].astype(str)


# '자치구+법정동 코드'와 '법정동코드'를 기준으로 행정동코드를 추가하는 방법
df = df.merge(df_ref[['법정동코드', '행정동코드']], 
              left_on='자치구+법정동 코드', 
              right_on='법정동코드', 
              how='left')

# '법정동코드' 컬럼 제거 (불필요한 경우)
df = df.drop(columns=['법정동코드','행정동코드_y'])
df
# Out:
#          접수연도  자치구코드 자치구명  법정동코드_x 법정동명  지번구분 지번구분명     본번   부번        건물명  \
# 0        2024  11215  광진구    10200   능동   1.0    대지  240.0  7.0    (240-7)
# 1        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 2        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 3        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 4        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# ...       ...    ...  ...      ...  ...   ...   ...    ...  ...        ...
# 7329768  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329769  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329770  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329771  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329772  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
#
# ...

# %%
df = df.drop(columns='행정동코드')
df
# Out:
#          접수연도  자치구코드 자치구명  법정동코드_x 법정동명  지번구분 지번구분명     본번   부번        건물명  \
# 0        2024  11215  광진구    10200   능동   1.0    대지  240.0  7.0    (240-7)
# 1        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 2        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 3        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 4        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# ...       ...    ...  ...      ...  ...   ...   ...    ...  ...        ...
# 7329768  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329769  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329770  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329771  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 7329772  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
#
# ...

# %%
df_merged = df.merge(df_ref[['행정동코드', '읍면동명']], 
                     left_on='행정동코드_x', 
                     right_on='행정동코드', 
                     how='left')

# '행정동코드' 컬럼은 필요 없으므로 제거
df_merged = df_merged.drop(columns=['행정동코드'])
df_merged
# Out:
#          접수연도  자치구코드 자치구명  법정동코드_x 법정동명  지번구분 지번구분명     본번   부번        건물명  \
# 0        2024  11215  광진구    10200   능동   1.0    대지  240.0  7.0    (240-7)
# 1        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 2        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 3        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 4        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# ...       ...    ...  ...      ...  ...   ...   ...    ...  ...        ...
# 8581284  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581285  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581286  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581287  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581288  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
#
# ...

# %%
df_unique = df_merged.drop_duplicates()
# Out:
#          접수연도  자치구코드 자치구명  법정동코드_x 법정동명  지번구분 지번구분명     본번   부번        건물명  \
# 0        2024  11215  광진구    10200   능동   1.0    대지  240.0  7.0    (240-7)
# 1        2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 49       2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 81       2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# 97       2024  11290  성북구    13300  정릉동   1.0    대지  494.0  0.0  중앙하이츠빌1단지
# ...       ...    ...  ...      ...  ...   ...   ...    ...  ...        ...
# 8581164  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581189  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581214  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581239  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
# 8581264  2024  11305  강북구    10100  미아동   NaN   NaN    NaN  NaN        NaN
#
# ...

# %%
len(df_unique['법정동코드_y'].unique())
# Out:
# 388

# %%
# '생성일자' 컬럼을 기준으로 최신 값을 선택하기 위한 인덱스 찾기
latest_idx = df_ref.groupby('법정동코드')['생성일자'].idxmax()

# 최신 인덱스를 사용하여 df_ref 필터링
df_ref_unique = df_ref.loc[latest_idx]

# df_ref에서 법정동코드를 기준으로 행정동코드를 매핑
mapping = df_ref_unique.set_index('법정동코드')['행정동코드']

# df의 자치구+법정동 코드를 df_ref의 행정동코드 값으로 변환
df['자치구+법정동 코드'] = df['자치구+법정동 코드'].map(mapping)

# %%
mapping
# Out:
# 법정동코드
# 1100000000    1100000000
# 1111000000    1111000000
# 1111010100    1111051500
# 1111010200    1111051500
# 1111010300    1111051500
#                  ...
# 5280042024    5280042000
# 5280042025    5280042000
# 5280042026    5280042000
# 5280042027    5280042000
# 5280042028    5280042000
# Name: 행정동코드, Length: 21809, dtype: object

# %%
# df_ref의 법정동코드와 행정동코드 컬럼을 object 형식으로 변환
df_ref['법정동코드'] = df_ref['법정동코드'].astype(str)
df_ref['행정동코드'] = df_ref['행정동코드'].astype(str)

# df_ref에서 법정동코드를 기준으로 행정동코드를 매핑
mapping = df_ref.set_index('법정동코드')['행정동코드']

# df의 법정동코드 값을 df_ref의 행정동코드 값으로 변환
df['자치구+법정동 코드'] = df['자치구+법정동 코드'].map(mapping)
df
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32496/2273033677.py in <module>
#       7
#       8 # df의 법정동코드 값을 df_ref의 행정동코드 값으로 변환
# ----> 9 df['자치구+법정동 코드'] = df['자치구+법정동 코드'].map(mapping)
#      10 df
#
# c:\Users\82103\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# c:\Users\82103\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     840             values = self._values
#     841
# --> 842             indexer = mapper.index.get_indexer(values)
# ...

# %%
df_ref['법정동코드'].unique
# Out:
# <bound method Series.unique of 0        1100000000
# 1        1111000000
# 2        1111010100
# 3        1111010200
# 4        1111010300
#             ...
# 21804    5280042024
# 21805    5280042025
# 21806    5280042026
# 21807    5280042027
# 21808    5280042028
# Name: 법정동코드, Length: 21809, dtype: object>

# %%
pip install pysqlite3
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\82103\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\82103\\AppData\\Local\\Temp\\pip-install-hzc4wrmx\\pysqlite3_9a2bc519a5304c3b8f1df86b0c94a0df\\setup.py'"'"'; __file__='"'"'C:\\Users\\82103\\AppData\\Local\\Temp\\pip-install-hzc4wrmx\\pysqlite3_9a2bc519a5304c3b8f1df86b0c94a0df\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\82103\AppData\Local\Temp\pip-wheel-az1g2eer'
# ...

# %%
import sqlite3

# 데이터베이스 연결
conn = sqlite3.connect('국토교통부_전국법정동20211217.sqlite')

# 커서 객체 생성
cur = conn.cursor()

# 이후 cur을 사용하여 SQL 쿼리 실행

# %%
import sqlite3  #pip install pysqlite3 
import re #정규식사용하게해주는 것


def myf질의행정동법정동코드(시도명, 시군구명, 읍면동명, 리명 = ' '): #사실 시도명은 필요없다. 리가 없는 것은 공백처리함
 
    if 리명 == ' ':  #경기도 용인시 처인구 포곡읍 신원리
        cur.execute('SELECT * FROM data where 시군구명 = "' +시군구명+  '" and  읍면동명 = "' +읍면동명+ '" and 삭제일자 IS NULL')
    else:   #경기도 성남시 수정구 수진동
        cur.execute('SELECT * FROM data where 시군구명 = "' +시군구명+ '" and  리명 = "' +리명+ '" and 삭제일자 IS NULL')


    rows = cur.fetchall()
    '''확인용
    for row in rows:
        print( row[0][0:5],row[0][5:10],   row)
    '''
    try:
        print( "행정동코드: ", rows[0][0][0:5], "   , 법정동코드: ", rows[0][0][5:10])
        return rows[0][0][0:5], rows[0][0][5:10]
    except:
        print(시도명, 시군구명, 읍면동명, 리명, "주소검색이 안되네요")
        return "",""
        

def myf주소나누기(전체주소):
    try:
        temp = re.search(' [0-9]', 전체주소).start()    #번지에서 자름
        my주소앞머리  = 전체주소[0:temp]
        my번지 = 전체주소[temp+1:100]
        try:
            temp = re.search('-', my번지).start()  #번지안에서 -에서 자름
            my번 = my번지[0:temp].strip()
            my지 = my번지[temp+1:100].strip()
        except:
            my번 = my번지.strip()
            my지 = ""
    except:
        my주소앞머리 = 전체주소 
        my번 = ""
        my지 = ""
    
    try:
        temp = re.search(' 산', my주소앞머리).start()    #번지에서 자름
        my주소앞머리  = 전체주소[0:temp]
        my산 = "산"
    except:
        my산 = ""
        
        pass
    

    temp = my주소앞머리.split() #주소를 일단 쉼표에서 다 나눔
    if len(temp) == 5: #리가 있는 곳
        #print("---리가 있는 곳인가 보네요")
        my시도 = temp[0].strip()
        my시군 = temp[1].strip()
        my구 = temp[2].strip()
        my읍면동 = temp[3].strip()
        my리 = temp[4].strip()
    elif len(temp) == 4: #일반 주소
        #print("---주소를 나눕니다")
        my시도 = temp[0].strip()
        my시군 = temp[1].strip()
        my구 = temp[2].strip()
        my읍면동 = temp[3].strip()
        my리 = " "  #리가 없는 것은 공백처리
    elif len(temp) == 3: #구가 없는 곳
        #print("---주소를 나눕니다")
        my시도 = temp[0].strip()
        my시군 = temp[1].strip()
        my구 = ""
        my읍면동 = temp[2].strip()
        my리 = " "  #리가 없는 것은 공백처리
    else:   #오류있는 것
        print("주소나누기가 안되네요. 띄어쓰기 등을 확인해 보세요...    ", 전체주소)
        return "","","","","","","",""

    print(전체주소,"를 다음처럼 변환했습니다.   ", my시도,"-", my시군,"-", my구,"-", my읍면동,"-", my리, my산, "- 번지는 ",  my번,", ", my지 )
    return my시도, my시군, my구, my읍면동, my리, my산, my번, my지


def myf행정동법정동코드변환(전체주소):
    temp = (myf주소나누기(전체주소))
    myCode = myf질의행정동법정동코드("", temp[1]+temp[2],temp[3], temp[4])
    return 전체주소, temp[0], temp[1], temp[2], temp[3], temp[4], temp[5], temp[6], temp[7], myCode[0], myCode[1] #0전체주소 1시도 2시군 3구 4읍면동 5리 6산 7번 8지 9행정동 10법정동

# %%
myf행정동법정동코드변환('서울특별시 성북구 정릉동 494')
# Out:
# 서울특별시 성북구 정릉동 494 를 다음처럼 변환했습니다.    서울특별시 - 성북구 -  - 정릉동 -    - 번지는  494 ,
# 행정동코드:  11290    , 법정동코드:  13300
# ('서울특별시 성북구 정릉동 494',
#  '서울특별시',
#  '성북구',
#  '',
#  '정릉동',
#  ' ',
#  '',
#  '494',
#  '',
#  '11290',
#  '13300')

# %%
df2 = pd.read_csv('주소3.csv', encoding ='utf-8')
df2
# Out:
#        접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번    부번           건물명  \
# 0      2024  11215  광진구  10200   능동   1.0    대지  240.0   7.0       (240-7)
# 1      2024  11290  성북구  13300  정릉동   1.0    대지  494.0   NaN     중앙하이츠빌1단지
# 2      2024  11620  관악구  10100  봉천동   1.0    대지  969.0  51.0      리더스 오피스텔
# 3      2024  11260  중랑구  10300  중화동   1.0    대지  329.0  25.0         해피리움빌
# 4      2024  11470  양천구  10100  신정동   1.0    대지  325.0   NaN      목동신시가지11
# ...     ...    ...  ...    ...  ...   ...   ...    ...   ...           ...
# 68818  2024  11215  광진구  10700  화양동   1.0    대지   17.0  68.0  세종에버그린(101동)
# 68819  2024  11530  구로구  10700  개봉동   1.0    대지  170.0  33.0  금석연립(170-33)
# 68820  2024  11530  구로구  10700  개봉동   1.0    대지  170.0  33.0  금석연립(170-33)
# 68821  2024  11530  구로구  10700  개봉동   1.0    대지  170.0  33.0  금석연립(170-33)
# 68822  2024  11530  구로구  10700  개봉동   1.0    대지  170.0  33.0  금석연립(170-33)
#
# ...

# %%
df_till_30000 = df2.iloc[:30000]
df_till_30000
# Out:
#        접수연도  자치구코드 자치구명  법정동코드  법정동명  지번구분 지번구분명     본번    부번        건물명  ...  \
# 0      2024  11215  광진구  10200    능동   1.0    대지  240.0   7.0    (240-7)  ...
# 1      2024  11290  성북구  13300   정릉동   1.0    대지  494.0   NaN  중앙하이츠빌1단지  ...
# 2      2024  11620  관악구  10100   봉천동   1.0    대지  969.0  51.0   리더스 오피스텔  ...
# 3      2024  11260  중랑구  10300   중화동   1.0    대지  329.0  25.0      해피리움빌  ...
# 4      2024  11470  양천구  10100   신정동   1.0    대지  325.0   NaN   목동신시가지11  ...
# ...     ...    ...  ...    ...   ...   ...   ...    ...   ...        ...  ...
# 29995  2024  11710  송파구  10500   석촌동   1.0    대지  261.0   5.0   작은것이아름답다  ...
# 29996  2024  11290  성북구  13600  하월곡동   1.0    대지  228.0   NaN    꿈의숲푸르지오  ...
# 29997  2024  11290  성북구  10300   돈암동   1.0    대지  609.0   1.0  한진(609-1)  ...
# 29998  2024  11110  종로구  13500   관철동   1.0    대지  155.0   NaN      종로1번가  ...
# 29999  2024  11590  동작구  10200   상도동   1.0    대지   29.0  62.0    행복파크빌리지  ...
#
# ...

# %% [markdown]
# ## 매핑

# %%
pip install geopandas
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\82103\anaconda3\lib\site-packages)
# ...

# %%
import geopandas as gpd

# %%
df3 = gpd.read_file("BND_ADM_DONG_PG/BND_ADM_DONG_PG.shp", encoding = "cp949")
df3
# Out:
#      BASE_DATE ADM_NM    ADM_CD  \
# 0     20230701    사직동  11010530
# 1     20230701    삼청동  11010540
# 2     20230701    부암동  11010550
# 3     20230701    평창동  11010560
# 4     20230701    한남동  11030740
# ...        ...    ...       ...
# 3523  20230701   운정6동  31200516
# 3524  20230701   운정5동  31200515
# 3525  20230701    새롬동  29010521
# 3526  20230701    도담동  29010514
# 3527  20230701    원문동  31110522
#
#                                                geometry
# 0     POLYGON ((197702.069 553187.311, 197703.431 55...
# 1     POLYGON ((198170.457 553770.678, 198172.189 55...
# 2     POLYGON ((196621.023 556395.88, 196628.323 556...
# 3     POLYGON ((197800.719 559064.245, 197782.581 55...
# 4     POLYGON ((200404.268 550031.323, 200404.019 55...
# ...                                                 ...
# 3523  POLYGON ((176367.906 568550.646, 176366.742 56...
# 3524  POLYGON ((176896.77 570836.185, 176894.169 570...
# 3525  POLYGON ((223193.497 431749.316, 223183.276 43...
# ...

# %%
df3.to_crs(epsg = 4326, inplace = True)
df3.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import requests
import pprint
import json

# %%
from tqdm import tqdm
import requests

# TQDM 설정
tqdm.pandas()

# API 요청 함수 정의
def geocoding(address):
    apiurl = "https://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": address,  # 각 주소가 여기에 들어감
        "format": "json",
        "type": "road",  # 도로명 주소
        "key": "4CEAC6CC-EBAF-3B84-ADC4-328276425DF5"  # 발급받은 API Key
    }
    
    try:
        response = requests.get(apiurl, params=params)
        if response.status_code == 200:
            data = response.json()
            if data['response']['status'] == 'OK':
                x = data['response']['result']['point']['x']  # 경도
                y = data['response']['result']['point']['y']  # 위도
                return x, y  # 좌표 반환
            else:
                return None, None  # API에서 오류 발생 시 None 반환
        else:
            return None, None  # HTTP 요청 오류 시 None 반환
    except Exception as e:
        print(f"Error occurred for address: {address}, Error: {e}")
        return None, None  # 예외 발생 시 None 반환

# 주소 열에 대해 순차적으로 API 호출 및 진행 상황 표시
df_till_30000['경도'], df_till_30000['위도'] = zip(*df_till_30000['주소'].progress_apply(geocoding))

# 결과 확인
print(df_till_30000[['주소', '경도', '위도']])
# Out:
# 100%|██████████| 30000/30000 [1:04:57<00:00,  7.70it/s]
#                        주소             경도            위도
# 0        서울시 광진구 능동 240-7           None          None
# 1         서울시 성북구 정릉동 494           None          None
# 2      서울시 관악구 봉천동 969-51           None          None
# 3      서울시 중랑구 중화동 329-25           None          None
# 4         서울시 양천구 신정동 325  126.857164737  37.521856902
# ...                   ...            ...           ...
# 29995   서울시 송파구 석촌동 261-5           None          None
# 29996    서울시 성북구 하월곡동 228           None          None
# 29997   서울시 성북구 돈암동 609-1           None          None
# 29998     서울시 종로구 관철동 155           None          None
# 29999   서울시 동작구 상도동 29-62           None          None
#
# [30000 rows x 3 columns]
# C:\Users\82103\AppData\Local\Temp/ipykernel_3536/812442006.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_till_30000
# Out:
#        접수연도  자치구코드 자치구명  법정동코드  법정동명  지번구분 지번구분명     본번    부번        건물명  ...  \
# 0      2024  11215  광진구  10200    능동   1.0    대지  240.0   7.0    (240-7)  ...
# 1      2024  11290  성북구  13300   정릉동   1.0    대지  494.0   NaN  중앙하이츠빌1단지  ...
# 2      2024  11620  관악구  10100   봉천동   1.0    대지  969.0  51.0   리더스 오피스텔  ...
# 3      2024  11260  중랑구  10300   중화동   1.0    대지  329.0  25.0      해피리움빌  ...
# 4      2024  11470  양천구  10100   신정동   1.0    대지  325.0   NaN   목동신시가지11  ...
# ...     ...    ...  ...    ...   ...   ...   ...    ...   ...        ...  ...
# 29995  2024  11710  송파구  10500   석촌동   1.0    대지  261.0   5.0   작은것이아름답다  ...
# 29996  2024  11290  성북구  13600  하월곡동   1.0    대지  228.0   NaN    꿈의숲푸르지오  ...
# 29997  2024  11290  성북구  10300   돈암동   1.0    대지  609.0   1.0  한진(609-1)  ...
# 29998  2024  11110  종로구  13500   관철동   1.0    대지  155.0   NaN      종로1번가  ...
# 29999  2024  11590  동작구  10200   상도동   1.0    대지   29.0  62.0    행복파크빌리지  ...
#
# ...

# %%
df_till_30000.to_csv('위도 경도 tagging2.csv', index=False)

# %%
import requests
apiurl = "https://api.vworld.kr/req/address?"
params = {
	"service": "address",
	"request": "getcoord",
	"crs": "epsg:4326",
	"address": "판교로 242",
	"format": "json",
	"type": "road",
	"key": "4CEAC6CC-EBAF-3B84-ADC4-328276425DF5"
}

# %%
response = requests.get(apiurl, params=params)
if response.status_code == 200:
	print(response.json())
# Out:
# {'response': {'service': {'name': 'address', 'version': '2.0', 'operation': 'getcoord', 'time': '16(ms)'}, 'status': 'OK', 'input': {'type': 'road', 'address': '판교로 242'}, 'refined': {'text': '경기도 성남시 분당구 판교로 242 (삼평동)', 'structure': {'level0': '대한민국', 'level1': '경기도', 'level2': '성남시 분당구', 'level3': '삼평동', 'level4L': '판교로', 'level4LC': '', 'level4A': '삼평동', 'level4AC': '4113565500', 'level5': '242', 'detail': ''}}, 'result': {'crs': 'EPSG:4326', 'point': {'x': '127.101313354', 'y': '37.402352535'}}}}

# %%
df_tagged_fail = df2

# %%
from shapely.geometry import Point

# 경도와 위도가 None이 아닌 경우에만 Point 객체를 생성
df_till_30000['geometry'] = df_till_30000.apply(lambda row: Point([row['경도'], row['위도']]) if pd.notnull(row['경도']) and pd.notnull(row['위도']) else None, axis=1)

# 결과 확인
print(df_till_30000[['경도', '위도', 'geometry']])
# Out:
#                   경도            위도                            geometry
# 0               None          None                                None
# 1               None          None                                None
# 2               None          None                                None
# 3               None          None                                None
# 4      126.857164737  37.521856902  POINT (126.857164737 37.521856902)
# ...              ...           ...                                 ...
# 29995           None          None                                None
# 29996           None          None                                None
# 29997           None          None                                None
# 29998           None          None                                None
# 29999           None          None                                None
#
# [30000 rows x 3 columns]
# C:\Users\82103\AppData\Local\Temp/ipykernel_3536/3832037593.py:4: SettingWithCopyWarning:
# ...

# %%
df_till_30000 = gpd.GeoDataFrame(df_till_30000, geometry='geometry')
df_till_30000.set_crs(epsg=4326, inplace=True)
df_till_30000.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
df_final1 = gpd.sjoin(df3, df_till_30000, how = 'inner')
df_final1
# Out:
#      BASE_DATE ADM_NM    ADM_CD  \
# 0     20230701    사직동  11010530
# 0     20230701    사직동  11010530
# 0     20230701    사직동  11010530
# 0     20230701    사직동  11010530
# 0     20230701    사직동  11010530
# ...        ...    ...       ...
# 3483  20230701    인수동  11090750
# 3483  20230701    인수동  11090750
# 3483  20230701    인수동  11090750
# 3483  20230701    인수동  11090750
# 3483  20230701    인수동  11090750
#
#                                                geometry  index_right  접수연도  \
# 0     POLYGON ((126.97399 37.57823, 126.974 37.57809...         1462  2024
# 0     POLYGON ((126.97399 37.57823, 126.974 37.57809...        26677  2024
# 0     POLYGON ((126.97399 37.57823, 126.974 37.57809...        21969  2024
# 0     POLYGON ((126.97399 37.57823, 126.974 37.57809...        27947  2024
# 0     POLYGON ((126.97399 37.57823, 126.974 37.57809...        23953  2024
# ...                                                 ...          ...   ...
# ...

# %%
df_final1.columns
# Out:
# Index(['BASE_DATE', 'ADM_NM', 'ADM_CD', 'geometry', 'index_right', '접수연도',
#        '자치구코드', '자치구명', '법정동코드', '법정동명', '지번구분', '지번구분명', '본번', '부번', '건물명',
#        '계약일', '물건금액(만원)', '건물면적(㎡)', '토지면적(㎡)', '층', '권리구분', '취소일', '건축년도',
#        '건물용도', '신고구분', '신고한 개업공인중개사 시군구명', '주소', '경도', '위도'],
#       dtype='object')

# %%
df_final1.to_csv('행정동_till_30000.csv', index=False)

# %%
df_final1= df_final1[['ADM_NM','건물명']]
df_final1
# Out:
#      ADM_NM                  건물명
# 0       사직동  광화문스페이스본(101동~105동)
# 0       사직동  광화문스페이스본(101동~105동)
# 0       사직동  광화문스페이스본(101동~105동)
# 0       사직동  광화문스페이스본(101동~105동)
# 0       사직동  광화문스페이스본(101동~105동)
# ...     ...                  ...
# 3483    인수동                 삼우맨숀
# 3483    인수동               수유벽산1차
# 3483    인수동             어반빌리움 수유
# 3483    인수동             어반빌리움 수유
# 3483    인수동             어반빌리움 수유
#
# [4377 rows x 2 columns]

# %%
count_df = df_final1.groupby('ADM_NM').size().reset_index(name='count')
count_df
# Out:
#     ADM_NM  count
# 0     가락2동     61
# 1     가락본동     71
# 2     가양1동      5
# 3      가회동      1
# 4     갈현1동      2
# ..     ...    ...
# 262    효창동     29
# 263    후암동      5
# 264   휘경1동     46
# 265   휘경2동     14
# 266    흑석동     17
#
# [267 rows x 2 columns]

# %%
import pandas as pd

try:
    df5 = pd.read_csv('서울특별시 건축물대장 정보(2022년).csv', encoding='cp949', delimiter=';')
except pd.errors.ParserError as e:
    print(f"ParserError: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# c:\Users\82103\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df5
# Out:
#                       mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd  \
# 0                        11110-75495          11110-20425           집합
# 1                        11470-60089           11470-2769           집합
# 2                        11170-50025           11170-9414           집합
# 3                        11470-60070           11470-2769           집합
# 4                        11170-49651           11170-9414           집합
# ...                              ...                  ...          ...
# 657788                   11470-40641           11470-1482           집합
# 657789                   11470-40642           11470-1482           집합
# 657790                   11560-31365                  NaN           일반
# 657791  11710-1000000000000000885682           11710-3067           집합
# 657792  11710-1000000000000000885701           11710-3067           집합
#
#        regstr_kind_cd sigungu_cd bjdong_cd plat_gb_cd   bun  ji splot_nm  ...  \
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657793 entries, 0 to 657792
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   mgm_bldrgst_pk        657793 non-null  object
#  1   mgm_upper_bldrgst_pk  598572 non-null  object
#  2   regstr_gb_cd          657793 non-null  object
#  3   regstr_kind_cd        657793 non-null  object
#  4   sigungu_cd            657793 non-null  object
#  5   bjdong_cd             657793 non-null  object
#  6   plat_gb_cd            657793 non-null  object
#  7   bun                   657793 non-null  int64
#  8   ji                    657793 non-null  int64
#  9   splot_nm              1763 non-null    object
#  10  block                 998 non-null     object
#  11  lot                   794 non-null     object
#  12  bld_nm                535849 non-null  object
#  13  viol_bld_yn           16192 non-null   object
# ...

# %%
df5['na_main_bun'].unique()
# Out:
# array([  0.,  nan,   3.,  19.,   9.,   6.,   5.,  10.,  27.,   1.,  38.,
#          7.,   2.,  16.,  14.,  11.,  21.,  30.,   8.,  13.,  17.,   4.,
#         22.,  24.,  20.,  12.,  47.,  36.,  25.,  15.,  46.,  23.,  43.,
#         18.,  32.,  87.,  45.,  34.,  49.,  28.,  35.,  83.,  50.,  37.,
#         42.,  29.,  26.,  54.,  31., 117.,  71.,  44.,  62.,  41.,  40.,
#         33.,  39.,  59.,  86.,  48.,  51.,  80.,  58.,  55.,  53.,  66.,
#         75.,  78.,  61.,  96.,  60., 108.,  57., 109., 103.,  63.,  69.,
#         52., 104.,  93.,  56., 105.,  64., 101.,  68.,  65.,  97.,  67.,
#         72., 121.,  77.,  76., 137.,  99.,  79., 115.,  84.,  70., 151.,
#         73., 102., 125.])

# %%
df5['na_sub_bun']=df5['na_sub_bun'].astype('Int64')
df5['na_main_bun']=df5['na_main_bun'].astype('Int64')

df5['na_sub_bun'] = df5['na_sub_bun'].replace(0, np.nan)

df5 = df5.dropna(subset=['na_main_bun','na_road_cd'])

# %%
import numpy as np

def create_address(row):
    if pd.isna(row['na_sub_bun']):
        return f"{row['na_road_cd']} {row['na_main_bun']}"
    else:
        return f"{row['na_road_cd']} {row['na_main_bun']}-{row['na_sub_bun']}"

df5['주소'] = df5.apply(create_address, axis=1)
df5
# Out:
#        mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd  \
# 0         11110-75495          11110-20425           집합            전유부
# 1         11470-60089           11470-2769           집합            전유부
# 2         11170-50025           11170-9414           집합            전유부
# 3         11470-60070           11470-2769           집합            전유부
# 4         11170-49651           11170-9414           집합            전유부
# ...               ...                  ...          ...            ...
# 657786    11470-40621           11470-1482           집합            전유부
# 657787    11470-40622           11470-1482           집합            전유부
# 657788    11470-40641           11470-1482           집합            전유부
# 657789    11470-40642           11470-1482           집합            전유부
# 657790    11560-31365                  NaN           일반          일반건축물
#
#        sigungu_cd bjdong_cd plat_gb_cd   bun  ji splot_nm  ...  \
# ...

# %%
df5['주소']
# Out:
# 0               서울특별시 종로구 종로 347
# 1          서울특별시 양천구 남부순환로85길 16
# 2              서울특별시 용산구 한남대로 60
# 3          서울특별시 양천구 남부순환로85길 16
# 4              서울특별시 용산구 한남대로 60
#                    ...
# 657786         서울특별시 양천구 목동동로 10
# 657787         서울특별시 양천구 목동동로 10
# 657788         서울특별시 양천구 목동동로 10
# 657789         서울특별시 양천구 목동동로 10
# 657790    서울특별시 영등포구 대림로35길 12-1
# Name: 주소, Length: 655563, dtype: object

# %%
df5
# Out:
#        mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd  \
# 0         11110-75495          11110-20425           집합            전유부
# 1         11470-60089           11470-2769           집합            전유부
# 2         11170-50025           11170-9414           집합            전유부
# 3         11470-60070           11470-2769           집합            전유부
# 4         11170-49651           11170-9414           집합            전유부
# ...               ...                  ...          ...            ...
# 657786    11470-40621           11470-1482           집합            전유부
# 657787    11470-40622           11470-1482           집합            전유부
# 657788    11470-40641           11470-1482           집합            전유부
# 657789    11470-40642           11470-1482           집합            전유부
# 657790    11560-31365                  NaN           일반          일반건축물
#
#        sigungu_cd bjdong_cd plat_gb_cd   bun    ji splot_nm  ...  \
# ...

# %%
df5.to_csv('토지대장2.csv', index=False)

# %%
import pandas as pd

df6=pd.read_csv('토지대장2.csv')
df6
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_1184/3615389659.py:3: DtypeWarning: Columns (9,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6=pd.read_csv('토지대장2.csv')
#        mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd  \
# 0         11110-75495          11110-20425           집합            전유부
# 1         11470-60089           11470-2769           집합            전유부
# 2         11170-50025           11170-9414           집합            전유부
# 3         11470-60070           11470-2769           집합            전유부
# 4         11170-49651           11170-9414           집합            전유부
# ...               ...                  ...          ...            ...
# 655558    11470-40621           11470-1482           집합            전유부
# 655559    11470-40622           11470-1482           집합            전유부
# 655560    11470-40641           11470-1482           집합            전유부
# ...

# %%
df_selected = df6[df6['sigungu_cd'].isin(['송파구', '동대문구', '양천구'])]
df_selected
# Out:
#        mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd  \
# 1         11470-60089           11470-2769           집합            전유부
# 3         11470-60070           11470-2769           집합            전유부
# 49        11470-60091           11470-2769           집합            전유부
# 91        11470-60051           11470-2769           집합            전유부
# 99        11470-60087           11470-2769           집합            전유부
# ...               ...                  ...          ...            ...
# 655557    11470-40620           11470-1482           집합            전유부
# 655558    11470-40621           11470-1482           집합            전유부
# 655559    11470-40622           11470-1482           집합            전유부
# 655560    11470-40641           11470-1482           집합            전유부
# 655561    11470-40642           11470-1482           집합            전유부
#
#        sigungu_cd bjdong_cd plat_gb_cd   bun  ji splot_nm  ...  \
# ...

# %%
df_40000 =df_selected.iloc[:40000]
df_40001_70000=df_selected.iloc[40000:70000]
df_70001_end=df_selected.iloc[70000:]

# %%
print(len(df6_after_30000))
# Out:
# 625563

# %%
df_70001_end
# Out:
#          mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd  \
# 488311  11710-100499516      11710-100499503           집합            전유부
# 488313  11710-100499517      11710-100499503           집합            전유부
# 488315  11710-100504281                  NaN           집합            표제부
# 488317  11710-100504282      11710-100504281           집합            전유부
# 488319  11710-100504283      11710-100504281           집합            전유부
# ...                 ...                  ...          ...            ...
# 655557      11470-40620           11470-1482           집합            전유부
# 655558      11470-40621           11470-1482           집합            전유부
# 655559      11470-40622           11470-1482           집합            전유부
# 655560      11470-40641           11470-1482           집합            전유부
# 655561      11470-40642           11470-1482           집합            전유부
#
#        sigungu_cd bjdong_cd plat_gb_cd  bun  ji splot_nm  ...  \
# ...

# %%
from tqdm import tqdm
import requests

# TQDM 설정
tqdm.pandas()

# API 요청 함수 정의
def geocoding(address):
    apiurl = "https://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": address,  # 각 주소가 여기에 들어감
        "format": "json",
        "type": "road",  # 도로명 주소
        "key": "5440F99A-69DB-30C5-9FBB-9DAC38AA281E"  # 발급받은 API Key
    }
    
    try:
        response = requests.get(apiurl, params=params)
        if response.status_code == 200:
            data = response.json()
            if data['response']['status'] == 'OK':
                x = data['response']['result']['point']['x']  # 경도
                y = data['response']['result']['point']['y']  # 위도
                return x, y  # 좌표 반환
            else:
                return None, None  # API에서 오류 발생 시 None 반환
        else:
            return None, None  # HTTP 요청 오류 시 None 반환
    except Exception as e:
        print(f"Error occurred for address: {address}, Error: {e}")
        return None, None  # 예외 발생 시 None 반환

# 주소 열에 대해 순차적으로 API 호출 및 진행 상황 표시
df_70001_end['경도'], df_70001_end['위도'] = zip(*df_70001_end['주소'].progress_apply(geocoding))

# 결과 확인
print(df_70001_end[['주소', '경도', '위도']])
df_70001_end.to_csv('df_40001_70000.csv', index=False)
# Out:
#  48%|████▊     | 12114/25412 [13:31<8:23:02,  2.27s/it]
# Error occurred for address: 서울특별시 송파구 잠실로 88, Error: HTTPSConnectionPool(host='api.vworld.kr', port=443): Max retries exceeded with url: /req/address?service=address&request=getcoord&crs=epsg%3A4326&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%86%A1%ED%8C%8C%EA%B5%AC+%EC%9E%A0%EC%8B%A4%EB%A1%9C+88&format=json&type=road&key=5440F99A-69DB-30C5-9FBB-9DAC38AA281E (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FC82B1B4F0>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다'))
#  71%|███████   | 17937/25412 [20:32<4:42:41,  2.27s/it]
# ...

# %%
df6_30000_100000.to_csv('30000_100000.csv',index=False)

# %%
from shapely.geometry import Point

# 경도와 위도가 None이 아닌 경우에만 Point 객체를 생성
df_70001_end['geometry'] = df_70001_end.apply(lambda row: Point([row['경도'], row['위도']]) if pd.notnull(row['경도']) and pd.notnull(row['위도']) else None, axis=1)

# 결과 확인
print(df_70001_end[['경도', '위도', 'geometry']])
# Out:
#                    경도            위도                            geometry
# 488311  127.149886749  37.500137291  POINT (127.149886749 37.500137291)
# 488313  127.149886749  37.500137291  POINT (127.149886749 37.500137291)
# 488315  127.106023241  37.501697973  POINT (127.106023241 37.501697973)
# 488317  127.106023241  37.501697973  POINT (127.106023241 37.501697973)
# 488319  127.106023241  37.501697973  POINT (127.106023241 37.501697973)
# ...               ...           ...                                 ...
# 655557  126.859516051  37.510919191  POINT (126.859516051 37.510919191)
# 655558  126.859516051  37.510919191  POINT (126.859516051 37.510919191)
# 655559  126.859516051  37.510919191  POINT (126.859516051 37.510919191)
# 655560  126.859516051  37.510919191  POINT (126.859516051 37.510919191)
# 655561  126.859516051  37.510919191  POINT (126.859516051 37.510919191)
#
# [25412 rows x 3 columns]
# ...

# %%
df_70001_end = gpd.GeoDataFrame(df_70001_end, geometry='geometry')
df_70001_end.set_crs(epsg=4326, inplace=True)
df_70001_end.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
df_70001_end = gpd.sjoin(df3, df_70001_end, how = 'inner')
df_70001_end
# Out:
#      BASE_DATE ADM_NM    ADM_CD  \
# 118   20230701   휘경1동  11060720
# 118   20230701   휘경1동  11060720
# 118   20230701   휘경1동  11060720
# 118   20230701   휘경1동  11060720
# 118   20230701   휘경1동  11060720
# ...        ...    ...       ...
# 1650  20230701   잠실3동  11240800
# 1650  20230701   잠실3동  11240800
# 1650  20230701   잠실3동  11240800
# 1650  20230701   잠실3동  11240800
# 1650  20230701   잠실3동  11240800
#
#                                                geometry  index_right  \
# 118   POLYGON ((127.06521 37.59537, 127.06521 37.595...       546540
# 118   POLYGON ((127.06521 37.59537, 127.06521 37.595...       501348
# 118   POLYGON ((127.06521 37.59537, 127.06521 37.595...       582131
# 118   POLYGON ((127.06521 37.59537, 127.06521 37.595...       582129
# 118   POLYGON ((127.06521 37.59537, 127.06521 37.595...       501346
# ...                                                 ...          ...
# 1650  POLYGON ((127.09252 37.52319, 127.09359 37.521...       543764
# ...

# %%
df_final2.columns
# Out:
# Index(['BASE_DATE', 'ADM_NM', 'ADM_CD', 'geometry', 'index_right',
#        'mgm_bldrgst_pk', 'mgm_upper_bldrgst_pk', 'regstr_gb_cd',
#        'regstr_kind_cd', 'sigungu_cd', 'bjdong_cd', 'plat_gb_cd', 'bun', 'ji',
#        'splot_nm', 'block', 'lot', 'bld_nm', 'viol_bld_yn', 'regstr_seqno',
#        'recap_title_seqno', 'title_seqno', 'expos_seqno', 'na_road_cd',
#        'na_bjdong_cd', 'na_ugrnd_cd', 'na_main_bun', 'na_sub_bun', 'work_day',
#        '주소', '경도', '위도'],
#       dtype='object')

# %%
df_70001_end_selected= df_70001_end[['ADM_NM','주소']]
df_70001_end_selected
# Out:
#      ADM_NM                 주소
# 118    휘경1동  서울특별시 동대문구 망우로 29
# 118    휘경1동  서울특별시 동대문구 망우로 29
# 118    휘경1동  서울특별시 동대문구 망우로 29
# 118    휘경1동  서울특별시 동대문구 망우로 29
# 118    휘경1동  서울특별시 동대문구 망우로 29
# ...     ...                ...
# 1650   잠실3동   서울특별시 송파구 잠실로 62
# 1650   잠실3동   서울특별시 송파구 잠실로 62
# 1650   잠실3동   서울특별시 송파구 잠실로 62
# 1650   잠실3동   서울특별시 송파구 잠실로 62
# 1650   잠실3동   서울특별시 송파구 잠실로 62
#
# [25191 rows x 2 columns]

# %%
df_70001_end.to_csv('groupby전_40001_70000.csv', index=False)

# %%
count_df_70001_end = df_70001_end_selected.groupby('ADM_NM').size().reset_index(name='count')
count_df_70001_end
# Out:
#    ADM_NM  count
# 0    가락1동    108
# 1    가락2동    312
# 2    가락본동    311
# 3    거여1동     46
# 4    거여2동     66
# 5   답십리1동    312
# 6   답십리2동    336
# 7    마천1동    121
# 8    마천2동     94
# 9     목1동    363
# 10    목2동    221
# 11    목3동    352
# 12    목4동    356
# 13    목5동    512
# 14   문정1동    300
# 15   문정2동   4364
# 16   방이1동    147
# 17   방이2동    462
# 18    삼전동    368
# 19    석촌동    260
# 20   송파1동    391
# 21   송파2동    368
# 22   신월1동    240
# 23   신월2동    118
# 24   신월3동     62
# 25   신월4동    211
# 26   신월5동    100
# 27   신월6동     41
# 28   신월7동    128
# 29   신정1동    201
# 30   신정2동    217
# 31   신정3동    393
# 32   신정4동    504
# 33   신정6동    592
# 34   신정7동    741
# 35    오금동    576
# 36    오륜동    128
# 37    용신동    846
# 38    위례동   1736
# 39   이문1동     64
# 40   이문2동     87
# 41   잠실2동   1056
# 42   잠실3동    558
# 43   잠실4동   1040
# 44   잠실6동    180
# 45   잠실7동    365
# 46   잠실본동    642
# 47   장안1동    544
# 48   장안2동    184
# 49    장지동    205
# 50   전농1동    374
# ...

# %%
count_df_70001_end.to_csv('행정동별 개수_70001_end.csv', index=False)

# %%
one = pd.read_csv('행정동별 개수_40000.csv')
two = pd.read_csv('행정동별 개수_40001_70000.csv')
three = pd.read_csv('행정동별 개수_70001_end.csv')

# %%
building_total = pd.merge(one, two, on='ADM_NM', how='outer', suffixes=('_one', '_two'))
building_total = pd.merge(building_total, three, on='ADM_NM', how='outer')
building_total.rename(columns={'count': 'count_three'}, inplace=True)

# 개수 컬럼의 합을 계산 (NaN 값은 0으로 대체)
building_total['개수_total'] = building_total[['count_one', 'count_two', 'count_three']].fillna(0).sum(axis=1)

# %%
building_total = building_total[['ADM_NM','개수_total']]
building_total
# Out:
#    ADM_NM  개수_total
# 0    가락1동       352
# 1    가락2동      1633
# 2    가락본동      1983
# 3    거여1동       526
# 4    거여2동      1986
# 5   답십리1동      1312
# 6   답십리2동       962
# 7    마천1동      1359
# 8    마천2동       947
# 9     목1동      2062
# 10    목2동      1309
# 11    목3동      1319
# 12    목4동      1196
# 13    목5동      3668
# 14   문정1동       854
# 15   문정2동      7273
# 16   방이1동       916
# 17   방이2동      2793
# 18    삼전동      1309
# 19    석촌동      1685
# 20   송파1동      1297
# 21   송파2동      1166
# 22   신월1동      1117
# 23   신월2동       880
# 24   신월3동       439
# 25   신월4동       824
# 26   신월5동       503
# 27   신월6동       510
# 28   신월7동       820
# 29   신정1동      1812
# 30   신정2동      1672
# 31   신정3동      3629
# 32   신정4동      1748
# 33   신정6동      3033
# 34   신정7동      2375
# 35    오금동      1769
# 36    오륜동       405
# 37    용신동      3399
# 38    위례동      3672
# 39   이문1동       752
# 40   이문2동       367
# 41   잠실2동      2397
# 42   잠실3동      4530
# 43   잠실4동      2400
# ...

# %% [markdown]
# ## 취합

# %%
df_pop = pd.read_csv('인구+대기지수.csv',encoding='cp949')
df_pop
# Out:
#      자치구    행정동  주거인구   인구밀도    유동인구         노인인구수  통합대기환경지수_평균
# 0   동대문구  답십리1동   302  35222   83798  12371.499873    68.300345
# 1   동대문구  답십리2동   332  33006   74397  15455.988125    68.300345
# 2   동대문구    용신동   155  22445   90468  15976.336233    68.300345
# 3   동대문구   이문1동   176  20544   86466  15411.109831    68.300345
# 4   동대문구   이문2동   293  29251   52895  11048.353410    68.300345
# 5   동대문구   장안1동   273  30942   68237  12153.169593    68.300345
# 6   동대문구   장안2동   300  29986   78050  13059.343257    68.300345
# 7   동대문구   전농1동   254  24555   97169  19647.395497    68.300345
# 8   동대문구   전농2동   207  21662   26180   5480.740170    68.300345
# 9   동대문구    제기동   203  22444  102287  24634.742429    68.300345
# 10  동대문구   청량리동   163  15912   56441  16507.703546    68.300345
# 11  동대문구    회기동   131  17811   61333   9026.058789    68.300345
# 12  동대문구   휘경1동   247  25935  108001  16776.553303    68.300345
# 13  동대문구   휘경2동   215  23491   42131   7259.636831    68.300345
# ...

# %%
df_car = pd.read_csv('행정동별_등록차량대수_3.csv', encoding='utf-8')
df_car
# Out:
#            지역구      행정동     개수
# 0   서울특별시 동대문구   답십리1동    9849
# 1   서울특별시 동대문구   답십리2동    8665
# 2   서울특별시 동대문구     용신동   12369
# 3   서울특별시 동대문구    이문1동    3885
# 4   서울특별시 동대문구    이문2동    5377
# 5   서울특별시 동대문구    장안1동   13254
# 6   서울특별시 동대문구    장안2동   10914
# 7   서울특별시 동대문구    전농1동    9312
# 8   서울특별시 동대문구    전농2동    5451
# 9   서울특별시 동대문구     제기동    6148
# 10  서울특별시 동대문구    청량리동    4968
# 11  서울특별시 동대문구     회기동    2042
# 12  서울특별시 동대문구    휘경1동    3957
# 13  서울특별시 동대문구    휘경2동    6361
# 14   서울특별시 송파구    가락1동   11711
# 15   서울특별시 송파구    가락2동   10696
# 16   서울특별시 송파구    가락본동   13244
# 17   서울특별시 송파구    거여1동    4091
# 18   서울특별시 송파구    거여2동    7685
# 19   서울특별시 송파구    마천1동    5754
# 20   서울특별시 송파구    마천2동    5494
# 21   서울특별시 송파구    문정1동   11107
# 22   서울특별시 송파구    문정2동   14750
# 23   서울특별시 송파구    방이1동    6619
# 24   서울특별시 송파구    방이2동    7732
# 25   서울특별시 송파구     삼전동    8644
# 26   서울특별시 송파구     석촌동    9493
# 27   서울특별시 송파구    송파1동    7587
# 28   서울특별시 송파구    송파2동    6565
# ...

# %%
df_subway = pd.read_csv('지하철승객수_최종.csv')
df_subway=df_subway.drop(columns='Unnamed: 0')
df_subway
# Out:
#       gu  dong      avg_get
# 0   동대문구   용신동   342.849831
# 1   동대문구  장안1동   326.117872
# 2   동대문구  장안2동   326.117872
# 3   동대문구  전농1동   261.091727
# 4   동대문구   제기동   243.966662
# 5    송파구  가락1동   594.907272
# 6    송파구  가락2동   129.940543
# 7    송파구  가락본동   428.634206
# 8    송파구  거여1동   198.801403
# 9    송파구  마천1동   140.162783
# 10   송파구  문정1동   353.457364
# 11   송파구  문정2동   353.457364
# 12   송파구  방이1동   148.451034
# 13   송파구  방이2동   307.945279
# 14   송파구   삼전동   123.862907
# 15   송파구   석촌동   310.611700
# 16   송파구   오금동   174.463981
# 17   송파구   오륜동   261.071134
# 18   송파구  잠실2동   738.783424
# 19   송파구  잠실4동   382.407879
# 20   송파구  잠실6동  1723.168537
# 21   송파구  잠실7동   317.931659
# 22   송파구  잠실본동   128.322680
# 23   송파구   장지동   397.898045
# 24   양천구   목1동   732.589842
# 25   양천구   목2동    70.353140
# 26   양천구   목3동   204.808709
# 27   양천구  신정1동   169.076474
# 28   양천구  신정4동   236.128638
# 29   양천구  신정7동   115.841638

# %%
# 양쪽 데이터프레임의 '행정동' 컬럼에서 공백 제거
df_pop['행정동'] = df_pop['행정동'].str.strip()
df_car['행정동'] = df_car['행정동'].str.strip()

# 두 데이터프레임을 '행정동' 컬럼을 기준으로 병합
df_merged = pd.merge(df_pop, df_car[['행정동', '개수']], on='행정동', how='left')

# 결과 출력
df_merged
# Out:
#      자치구    행정동  주거인구   인구밀도    유동인구         노인인구수  통합대기환경지수_평균     개수
# 0   동대문구  답십리1동   302  35222   83798  12371.499873    68.300345   9849
# 1   동대문구  답십리2동   332  33006   74397  15455.988125    68.300345   8665
# 2   동대문구    용신동   155  22445   90468  15976.336233    68.300345  12369
# 3   동대문구   이문1동   176  20544   86466  15411.109831    68.300345   3885
# 4   동대문구   이문2동   293  29251   52895  11048.353410    68.300345   5377
# 5   동대문구   장안1동   273  30942   68237  12153.169593    68.300345  13254
# 6   동대문구   장안2동   300  29986   78050  13059.343257    68.300345  10914
# 7   동대문구   전농1동   254  24555   97169  19647.395497    68.300345   9312
# 8   동대문구   전농2동   207  21662   26180   5480.740170    68.300345   5451
# 9   동대문구    제기동   203  22444  102287  24634.742429    68.300345   6148
# 10  동대문구   청량리동   163  15912   56441  16507.703546    68.300345   4968
# 11  동대문구    회기동   131  17811   61333   9026.058789    68.300345   2042
# ...

# %%
df_combined = pd.read_csv('따릉이_녹지_최종.csv', encoding = 'utf-8')
df_combined = df_combined[:len(df_combined)-1]
df_combined
# Out:
#      지역구    행정동  따릉이 개수  녹지 개수
# 0   동대문구  답십리1동     7.0   12.0
# 1   동대문구  답십리2동     6.0    2.0
# 2   동대문구    용신동    18.0   16.0
# 3   동대문구   이문1동     3.0    3.0
# 4   동대문구   이문2동     7.0    3.0
# 5   동대문구   장안1동     5.0    8.0
# 6   동대문구   장안2동     5.0   15.0
# 7   동대문구   전농1동     7.0   11.0
# 8   동대문구   전농2동    10.0    6.0
# 9   동대문구    제기동     7.0    6.0
# 10  동대문구   청량리동    11.0    3.0
# 11  동대문구    회기동     2.0    0.0
# 12  동대문구   휘경1동     5.0    2.0
# 13  동대문구   휘경2동     7.0    2.0
# 14   송파구   가락1동     9.0   18.0
# 15   송파구   가락2동     6.0    0.0
# 16   송파구   가락본동     9.0    1.0
# 17   송파구   거여1동     6.0    2.0
# 18   송파구   거여2동     5.0    0.0
# 19   송파구   마천1동     5.0    0.0
# 20   송파구   마천2동     6.0    0.0
# 21   송파구   문정1동     5.0    0.0
# 22   송파구   문정2동    23.0    4.0
# 23   송파구   방이1동     8.0    3.0
# 24   송파구   방이2동     3.0    7.0
# 25   송파구    삼전동     5.0    2.0
# 26   송파구    석촌동     5.0    0.0
# 27   송파구   송파1동     5.0    1.0
# 28   송파구   송파2동     5.0    4.0
# ...

# %%
# 양쪽 데이터프레임의 '행정동' 컬럼에서 공백 제거
df_combined['행정동'] = df_combined['행정동'].str.strip()

# 두 데이터프레임을 '행정동' 컬럼을 기준으로 병합
df_merged = pd.merge(df_merged, df_combined[['행정동', '따릉이 개수','녹지 개수']], on='행정동', how='left')

# 결과 출력
df_merged
building_total
# Out:
#      자치구    행정동  주거인구   인구밀도    유동인구         노인인구수  통합대기환경지수_평균     개수  \
# 0   동대문구  답십리1동   302  35222   83798  12371.499873    68.300345   9849
# 1   동대문구  답십리2동   332  33006   74397  15455.988125    68.300345   8665
# 2   동대문구    용신동   155  22445   90468  15976.336233    68.300345  12369
# 3   동대문구   이문1동   176  20544   86466  15411.109831    68.300345   3885
# 4   동대문구   이문2동   293  29251   52895  11048.353410    68.300345   5377
# 5   동대문구   장안1동   273  30942   68237  12153.169593    68.300345  13254
# 6   동대문구   장안2동   300  29986   78050  13059.343257    68.300345  10914
# 7   동대문구   전농1동   254  24555   97169  19647.395497    68.300345   9312
# 8   동대문구   전농2동   207  21662   26180   5480.740170    68.300345   5451
# 9   동대문구    제기동   203  22444  102287  24634.742429    68.300345   6148
# 10  동대문구   청량리동   163  15912   56441  16507.703546    68.300345   4968
# 11  동대문구    회기동   131  17811   61333   9026.058789    68.300345   2042
# ...

# %%
building_total.columns = ['행정동','건물 개수']

# %%
# 양쪽 데이터프레임의 '행정동' 컬럼에서 공백 제거
building_total['행정동'] = building_total['행정동'].str.strip()

# 두 데이터프레임을 '행정동' 컬럼을 기준으로 병합
df_merged = pd.merge(df_merged, building_total[['행정동', '건물 개수']], on='행정동', how='left')

# 결과 출력
df_merged
# Out:
#      자치구    행정동  주거인구   인구밀도    유동인구         노인인구수  통합대기환경지수_평균     개수  \
# 0   동대문구  답십리1동   302  35222   83798  12371.499873    68.300345   9849
# 1   동대문구  답십리2동   332  33006   74397  15455.988125    68.300345   8665
# 2   동대문구    용신동   155  22445   90468  15976.336233    68.300345  12369
# 3   동대문구   이문1동   176  20544   86466  15411.109831    68.300345   3885
# 4   동대문구   이문2동   293  29251   52895  11048.353410    68.300345   5377
# 5   동대문구   장안1동   273  30942   68237  12153.169593    68.300345  13254
# 6   동대문구   장안2동   300  29986   78050  13059.343257    68.300345  10914
# 7   동대문구   전농1동   254  24555   97169  19647.395497    68.300345   9312
# 8   동대문구   전농2동   207  21662   26180   5480.740170    68.300345   5451
# 9   동대문구    제기동   203  22444  102287  24634.742429    68.300345   6148
# 10  동대문구   청량리동   163  15912   56441  16507.703546    68.300345   4968
# 11  동대문구    회기동   131  17811   61333   9026.058789    68.300345   2042
# ...

# %%
df_merged.rename(columns={'개수': '등록차량 개수'}, inplace=True)

# %%
df_merged.columns
# Out:
# Index(['자치구', '행정동', '주거인구', '인구밀도', '유동인구', '노인인구수', '통합대기환경지수_평균', '등록차량 개수',
#        '따릉이 개수', '녹지 개수', '건물 개수'],
#       dtype='object')

# %%
desired_columns = ['자치구', '행정동', '주거인구', '인구밀도', '유동인구', '노인인구수','등록차량 개수','따릉이 개수','녹지 개수','건물 개수','통합대기환경지수_평균']

# 컬럼 순서 재정렬
df_merged = df_merged[desired_columns]
df_merged
# Out:
#      자치구    행정동  주거인구   인구밀도    유동인구         노인인구수  등록차량 개수  따릉이 개수  녹지 개수  \
# 0   동대문구  답십리1동   302  35222   83798  12371.499873     9849     7.0   12.0
# 1   동대문구  답십리2동   332  33006   74397  15455.988125     8665     6.0    2.0
# 2   동대문구    용신동   155  22445   90468  15976.336233    12369    18.0   16.0
# 3   동대문구   이문1동   176  20544   86466  15411.109831     3885     3.0    3.0
# 4   동대문구   이문2동   293  29251   52895  11048.353410     5377     7.0    3.0
# 5   동대문구   장안1동   273  30942   68237  12153.169593    13254     5.0    8.0
# 6   동대문구   장안2동   300  29986   78050  13059.343257    10914     5.0   15.0
# 7   동대문구   전농1동   254  24555   97169  19647.395497     9312     7.0   11.0
# 8   동대문구   전농2동   207  21662   26180   5480.740170     5451    10.0    6.0
# 9   동대문구    제기동   203  22444  102287  24634.742429     6148     7.0    6.0
# 10  동대문구   청량리동   163  15912   56441  16507.703546     4968    11.0    3.0
# ...

# %%
df_merged.to_csv('지하철없는최종.csv', index=False)

# %%
import pandas as pd

df_real_final = pd.read_csv('대기환경_위경도변환완.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df_real_final = pd.read_csv('대기환경_위경도변환완.csv')
#
# AttributeError: module 'pandas' has no attribute 'read_csv'
